# %%
import pandas as pd
import numpy as np
import torch
from torch.utils.data import Dataset, DataLoader
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertForSequenceClassification
from transformers import AdamW
from sklearn.metrics import classification_report

# %%
train_df = pd.read_csv('DBPEDIA_train.csv')
val_df = pd.read_csv('DBPEDIA_val.csv')
test_df = pd.read_csv('DBPEDIA_test.csv')

# %%
# Combine l1, l2, l3 into a single column for labels
train_df['labels'] = train_df[['l1', 'l2', 'l3']].apply(lambda x: f'{x[0]} > {x[1]} > {x[2]}', axis=1)
val_df['labels'] = val_df[['l1', 'l2', 'l3']].apply(lambda x: f'{x[0]} > {x[1]} > {x[2]}', axis=1)
test_df['labels'] = test_df[['l1', 'l2', 'l3']].apply(lambda x: f'{x[0]} > {x[1]} > {x[2]}', axis=1)
# Out:
# <ipython-input-5-156112e65d30>:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   train_df['labels'] = train_df[['l1', 'l2', 'l3']].apply(lambda x: f'{x[0]} > {x[1]} > {x[2]}', axis=1)
# <ipython-input-5-156112e65d30>:3: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   val_df['labels'] = val_df[['l1', 'l2', 'l3']].apply(lambda x: f'{x[0]} > {x[1]} > {x[2]}', axis=1)
# <ipython-input-5-156112e65d30>:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   test_df['labels'] = test_df[['l1', 'l2', 'l3']].apply(lambda x: f'{x[0]} > {x[1]} > {x[2]}', axis=1)

# %%
# Encode labels
le = LabelEncoder()
train_df['label_encoded'] = le.fit_transform(train_df['labels'])
val_df['label_encoded'] = le.transform(val_df['labels'])
test_df['label_encoded'] = le.transform(test_df['labels'])

# %%
# Tokenize the text data
def tokenize_text(text, vocab):
    return [vocab[word] if word in vocab else vocab['<UNK>'] for word in text.split()]

# Pad sequences to the same length
def pad_sequences(sequences, maxlen):
    return np.array([np.pad(seq, (0, maxlen - len(seq)), mode='constant') if len(seq) < maxlen else seq[:maxlen] for seq in sequences])

# Create a vocabulary from the training data
vocab = {'<PAD>': 0, '<UNK>': 1}
for text in train_df['text']:
    for word in text.split():
        if word not in vocab:
            vocab[word] = len(vocab)

# Tokenize and pad the text data
maxlen = 100  # Maximum sequence length
train_texts = pad_sequences([tokenize_text(text, vocab) for text in train_df['text']], maxlen)
val_texts = pad_sequences([tokenize_text(text, vocab) for text in val_df['text']], maxlen)
test_texts = pad_sequences([tokenize_text(text, vocab) for text in test_df['text']], maxlen)

# %%
class CustomTextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = torch.tensor(texts, dtype=torch.long)
        self.labels = torch.tensor(labels, dtype=torch.long)

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {'text': self.texts[idx], 'label': self.labels[idx]}

train_dataset = CustomTextDataset(train_texts, train_df['label_encoded'])
val_dataset = CustomTextDataset(val_texts, val_df['label_encoded'])
test_dataset = CustomTextDataset(test_texts, test_df['label_encoded'])

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)

# %%
import torch.nn as nn

class LSTMClassifier(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim, output_dim, num_layers, dropout):
        super(LSTMClassifier, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, num_layers=num_layers,
                            dropout=dropout, batch_first=True, bidirectional=True)
        self.fc = nn.Linear(hidden_dim * 2, output_dim)  # *2 for bidirectional
        self.softmax = nn.Softmax(dim=1)

    def forward(self, text):
        embedded = self.embedding(text)
        lstm_out, _ = self.lstm(embedded)
        avg_pool = torch.mean(lstm_out, dim=1)
        logits = self.fc(avg_pool)
        output = self.softmax(logits)
        return output

# Model parameters
embedding_dim = 128
hidden_dim = 256
output_dim = len(le.classes_)
num_layers = 2
dropout = 0.5

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = LSTMClassifier(len(vocab), embedding_dim, hidden_dim, output_dim, num_layers, dropout)
model.to(device)
# Out:
# LSTMClassifier(
#   (embedding): Embedding(1091095, 128)
#   (lstm): LSTM(128, 256, num_layers=2, batch_first=True, dropout=0.5, bidirectional=True)
#   (fc): Linear(in_features=512, out_features=219, bias=True)
#   (softmax): Softmax(dim=1)
# )

# %%
import torch.optim as optim
from tqdm  import tqdm

optimizer = optim.Adam(model.parameters(), lr=1e-3)
criterion = nn.CrossEntropyLoss()

def train_epoch(model, data_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    loop = tqdm(data_loader, leave=True)

    for batch in loop:
        texts = batch['text'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(texts)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        loop.set_description(f"Train Loss: {total_loss / (loop.n + 1):.4f}")

    return total_loss / len(data_loader)

# Training loop
n_epochs = 3
for epoch in range(n_epochs):
    print(f'Epoch {epoch + 1}/{n_epochs}')
    train_loss = train_epoch(model, train_loader, optimizer, criterion)
    print(f'Training Loss: {train_loss}')
# Out:
# Epoch 1/3
# Train Loss: 5.3758: 100%|██████████| 7530/7530 [08:27<00:00, 14.83it/s]
# Training Loss: 5.375785676289998
# Epoch 2/3
# Train Loss: 5.3312: 100%|██████████| 7530/7530 [08:34<00:00, 14.64it/s]
# Training Loss: 5.3304553257358345
# Epoch 3/3
# Train Loss: 5.1113: 100%|██████████| 7530/7530 [08:31<00:00, 14.71it/s]
# Training Loss: 5.111302017184051

# %%
from sklearn.metrics import classification_report

def evaluate(model, data_loader):
    model.eval()
    predictions, true_labels = [], []
    loop = tqdm(data_loader, leave=True)

    with torch.no_grad():
        for batch in loop:
            texts = batch['text'].to(device)
            labels = batch['label'].to(device)

            outputs = model(texts)
            preds = torch.argmax(outputs, dim=1)

            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

    return classification_report(true_labels, predictions, target_names=le.classes_)

print(evaluate(model, val_loader))
# Out:
# 100%|██████████| 1126/1126 [00:08<00:00, 134.51it/s]
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#                                                                     precision    recall  f1-score   support
#
#                                         Agent > Actor > AdultActor       0.00      0.00      0.00       125
#                                         Agent > Actor > VoiceActor       0.00      0.00      0.00        52
#                                          Agent > Artist > Comedian       0.00      0.00      0.00       127
#                                     Agent > Artist > ComicsCreator       0.00      0.00      0.00       268
#                                   Agent > Artist > FashionDesigner       0.00      0.00      0.00        70
#                                           Agent > Artist > Painter       0.00      0.00      0.00       233
#                                      Agent > Artist > Photographer       0.00      0.00      0.00        41
#                    Agent > Athlete > AustralianRulesFootballPlayer       0.00      0.00      0.00       284
#                                  Agent > Athlete > BadmintonPlayer       0.00      0.00      0.00       136
#                                   Agent > Athlete > BaseballPlayer       0.33      0.90      0.49       272
#                                 Agent > Athlete > BasketballPlayer       0.84      0.94      0.89       285
#                                      Agent > Athlete > Bodybuilder       0.00      0.00      0.00        25
#                                         Agent > Athlete > Canoeist       0.00      0.00      0.00        44
#                                      Agent > Athlete > ChessPlayer       0.00      0.00      0.00       137
#                                        Agent > Athlete > Cricketer       0.50      0.96      0.65       269
#                                          Agent > Athlete > Cyclist       0.65      0.89      0.75       286
#                                      Agent > Athlete > DartsPlayer       0.00      0.00      0.00        53
#                                Agent > Athlete > GaelicGamesPlayer       0.59      0.97      0.73       286
#                                       Agent > Athlete > GolfPlayer       0.77      0.99      0.87       285
#                                          Agent > Athlete > Gymnast       0.52      0.97      0.68       287
#                                   Agent > Athlete > HandballPlayer       0.00      0.00      0.00       217
#                                       Agent > Athlete > HorseRider       0.00      0.00      0.00        61
#                                           Agent > Athlete > Jockey       0.00      0.00      0.00        51
#                                   Agent > Athlete > LacrossePlayer       0.00      0.00      0.00        41
#                                    Agent > Athlete > MartialArtist       0.27      0.86      0.41       285
#                                    Agent > Athlete > NetballPlayer       0.00      0.00      0.00        25
#                                      Agent > Athlete > PokerPlayer       0.00      0.00      0.00        65
#                                            Agent > Athlete > Rower       0.00      0.00      0.00        27
#                                      Agent > Athlete > RugbyPlayer       0.00      0.00      0.00       283
#                                     Agent > Athlete > SoccerPlayer       0.00      0.00      0.00       285
#                                     Agent > Athlete > SquashPlayer       0.00      0.00      0.00        40
#                                          Agent > Athlete > Swimmer       0.25      0.72      0.37       285
#                                Agent > Athlete > TableTennisPlayer       0.00      0.00      0.00        49
#                                     Agent > Athlete > TennisPlayer       0.75      0.99      0.86       286
#                                       Agent > Boxer > AmateurBoxer       0.00      0.00      0.00        43
#                                   Agent > BritishRoyalty > Baronet       0.00      0.00      0.00        73
#                             Agent > Broadcaster > BroadcastNetwork       0.00      0.00      0.00       124
#                                 Agent > Broadcaster > RadioStation       0.50      0.97      0.66       281
#                            Agent > Broadcaster > TelevisionStation       0.23      0.94      0.36       285
#                                          Agent > Cleric > Cardinal       0.00      0.00      0.00        73
#                                   Agent > Cleric > ChristianBishop       0.07      0.96      0.14       283
#                                              Agent > Cleric > Pope       0.00      0.00      0.00        36
#                                             Agent > Cleric > Saint       0.00      0.00      0.00       284
#                                       Agent > Coach > CollegeCoach       0.00      0.00      0.00       283
#                        Agent > ComicsCharacter > AnimangaCharacter       0.00      0.00      0.00        22
#                                          Agent > Company > Airline       0.44      0.95      0.60       285
#                                             Agent > Company > Bank       0.00      0.00      0.00       285
#                                          Agent > Company > Brewery       0.00      0.00      0.00        26
#                                       Agent > Company > BusCompany       0.00      0.00      0.00       140
#                                          Agent > Company > LawFirm       0.00      0.00      0.00        48
#                                        Agent > Company > Publisher       0.00      0.00      0.00       141
#                                      Agent > Company > RecordLabel       0.82      0.93      0.87       285
#                                           Agent > Company > Winery       0.00      0.00      0.00        32
#                           Agent > EducationalInstitution > Library       0.00      0.00      0.00       100
#                            Agent > EducationalInstitution > School       0.08      0.79      0.15       282
#                        Agent > EducationalInstitution > University       0.00      0.00      0.00       281
#                    Agent > FictionalCharacter > MythologicalFigure       0.00      0.00      0.00        74
#                         Agent > FictionalCharacter > SoapCharacter       0.00      0.00      0.00       251
#            Agent > GridironFootballPlayer > AmericanFootballPlayer       0.67      0.93      0.78       286
#                                               Agent > Group > Band       0.00      0.00      0.00       275
#                            Agent > MotorcycleRider > SpeedwayRider       0.00      0.00      0.00        67
#                       Agent > MusicalArtist > ClassicalMusicArtist       0.00      0.00      0.00        30
#                                 Agent > Organisation > Legislature       0.00      0.00      0.00       170
#                                Agent > Organisation > MilitaryUnit       0.19      0.63      0.29       278
#                              Agent > Organisation > PoliticalParty       0.49      0.85      0.62       279
#                         Agent > Organisation > PublicTransitSystem       0.00      0.00      0.00       176
#                                  Agent > Organisation > TradeUnion       0.00      0.00      0.00       162
#                      Agent > OrganisationMember > SportsTeamMember       0.00      0.00      0.00        57
#                                        Agent > Person > Ambassador       0.00      0.00      0.00        60
#                                         Agent > Person > Architect       0.00      0.00      0.00       269
#                                         Agent > Person > Astronaut       0.00      0.00      0.00        60
#                                       Agent > Person > BeautyQueen       0.00      0.00      0.00       233
#                                    Agent > Person > BusinessPerson       0.00      0.00      0.00        74
#                                              Agent > Person > Chef       0.00      0.00      0.00        55
#                                         Agent > Person > Economist       0.00      0.00      0.00       111
#                                          Agent > Person > Engineer       0.00      0.00      0.00        75
#                                      Agent > Person > HorseTrainer       0.00      0.00      0.00        23
#                                        Agent > Person > Journalist       0.00      0.00      0.00       154
#                                             Agent > Person > Judge       0.00      0.00      0.00       276
#                                    Agent > Person > MilitaryPerson       0.00      0.00      0.00       273
#                                             Agent > Person > Model       0.00      0.00      0.00       157
#                                           Agent > Person > Monarch       0.00      0.00      0.00       240
#                                             Agent > Person > Noble       0.00      0.00      0.00       284
#                                      Agent > Person > OfficeHolder       0.00      0.00      0.00       270
#                                       Agent > Person > Philosopher       0.00      0.00      0.00       180
#                                   Agent > Person > PlayboyPlaymate       0.00      0.00      0.00        26
#                                         Agent > Person > Religious       0.00      0.00      0.00        95
#                                   Agent > Politician > Congressman       0.00      0.00      0.00       284
#                                      Agent > Politician > Governor       0.00      0.00      0.00       259
#                                         Agent > Politician > Mayor       0.00      0.00      0.00       176
#                            Agent > Politician > MemberOfParliament       0.17      0.96      0.28       283
#                                     Agent > Politician > President       0.00      0.00      0.00       205
#                                 Agent > Politician > PrimeMinister       0.00      0.00      0.00       134
#                                       Agent > Politician > Senator       0.00      0.00      0.00        77
#                                      Agent > Presenter > RadioHost       0.00      0.00      0.00        34
#                             Agent > RacingDriver > FormulaOneRacer       0.00      0.00      0.00        73
#                                Agent > RacingDriver > NascarDriver       0.00      0.00      0.00        96
#                                   Agent > Scientist > Entomologist       0.00      0.00      0.00        40
#                                       Agent > Scientist > Medician       0.00      0.00      0.00        47
#                              Agent > SportsLeague > BaseballLeague       0.00      0.00      0.00        32
#                            Agent > SportsLeague > BasketballLeague       0.00      0.00      0.00        53
#                             Agent > SportsLeague > IceHockeyLeague       0.00      0.00      0.00        29
#                                 Agent > SportsLeague > RugbyLeague       0.00      0.00      0.00        55
#                                Agent > SportsLeague > SoccerLeague       0.71      0.60      0.65       194
#                              Agent > SportsManager > SoccerManager       0.25      0.86      0.39       283
#                        Agent > SportsTeam > AustralianFootballTeam       0.00      0.00      0.00        44
#                                Agent > SportsTeam > BasketballTeam       0.78      0.82      0.80       174
#                          Agent > SportsTeam > CanadianFootballTeam       0.00      0.00      0.00        20
#                                   Agent > SportsTeam > CricketTeam       0.00      0.00      0.00        69
#                                   Agent > SportsTeam > CyclingTeam       0.00      0.00      0.00        45
#                                  Agent > SportsTeam > HandballTeam       0.00      0.00      0.00        36
#                                    Agent > SportsTeam > HockeyTeam       0.46      0.91      0.61       236
#                                     Agent > SportsTeam > RugbyClub       0.48      0.69      0.56       217
#                   Agent > VolleyballPlayer > BeachVolleyballPlayer       0.00      0.00      0.00        20
#                                 Agent > WinterSportPlayer > Curler       0.00      0.00      0.00        73
#                           Agent > WinterSportPlayer > FigureSkater       0.74      0.96      0.83       288
#                        Agent > WinterSportPlayer > IceHockeyPlayer       0.00      0.00      0.00       285
#                                 Agent > WinterSportPlayer > Skater       0.00      0.00      0.00        51
#                                  Agent > WinterSportPlayer > Skier       0.00      0.00      0.00       253
#                                    Agent > Wrestler > SumoWrestler       0.00      0.00      0.00        45
#                                         Agent > Writer > Historian       0.00      0.00      0.00        66
#                                              Agent > Writer > Poet       0.00      0.00      0.00        28
#                                      Agent > Writer > ScreenWriter       0.00      0.00      0.00        66
#                                 Device > Engine > AutomobileEngine       0.00      0.00      0.00        37
#                                  Event > NaturalEvent > Earthquake       0.00      0.00      0.00        79
#                                Event > NaturalEvent > SolarEclipse       0.00      0.00      0.00        35
#                                    Event > Olympics > OlympicEvent       0.73      0.98      0.83       287
#                                         Event > Race > CyclingRace       0.00      0.00      0.00        87
#                                           Event > Race > HorseRace       0.68      0.79      0.73       234
#                                 Event > SocietalEvent > Convention       0.00      0.00      0.00       215
#                                   Event > SocietalEvent > Election       0.83      0.83      0.83       281
#                               Event > SocietalEvent > FilmFestival       0.00      0.00      0.00        92
#                           Event > SocietalEvent > MilitaryConflict       0.24      0.86      0.38       266
#                              Event > SocietalEvent > MusicFestival       0.00      0.00      0.00        40
#                                Event > SportsEvent > FootballMatch       0.65      0.92      0.76       287
#                                    Event > SportsEvent > GrandPrix       0.00      0.00      0.00       130
#                        Event > SportsEvent > MixedMartialArtsEvent       0.00      0.00      0.00        78
#                               Event > SportsEvent > WrestlingEvent       0.00      0.00      0.00       118
#                                Event > Tournament > GolfTournament       0.00      0.00      0.00       178
#                              Event > Tournament > SoccerTournament       0.36      0.85      0.51       287
#                              Event > Tournament > TennisTournament       0.00      0.00      0.00       108
#             Event > Tournament > WomensTennisAssociationTournament       0.00      0.00      0.00        52
#                    Place > AmusementParkAttraction > RollerCoaster       0.00      0.00      0.00        72
#                                         Place > BodyOfWater > Lake       0.78      0.89      0.83       283
#                                          Place > Building > Castle       0.00      0.00      0.00       121
#                                Place > Building > HistoricBuilding       0.77      0.92      0.84       286
#                                        Place > Building > Hospital       0.00      0.00      0.00       286
#                                           Place > Building > Hotel       0.00      0.00      0.00       125
#                                          Place > Building > Museum       0.00      0.00      0.00       285
#                                          Place > Building > Prison       0.00      0.00      0.00       132
#                                      Place > Building > Restaurant       0.00      0.00      0.00       111
#                                    Place > Building > ShoppingMall       0.00      0.00      0.00       253
#                                     Place > CelestialBody > Galaxy       0.00      0.00      0.00        83
#                                     Place > CelestialBody > Planet       0.76      0.91      0.83       282
#                     Place > ClericalAdministrativeRegion > Diocese       0.94      0.93      0.93       287
#                                   Place > Infrastructure > Airport       0.54      0.88      0.67       286
#                                       Place > Infrastructure > Dam       0.00      0.00      0.00       287
#                                        Place > NaturalPlace > Cave       0.00      0.00      0.00        50
#                                     Place > NaturalPlace > Glacier       0.00      0.00      0.00        67
#                                    Place > NaturalPlace > Mountain       0.00      0.00      0.00       282
#                                Place > NaturalPlace > MountainPass       0.00      0.00      0.00       104
#                               Place > NaturalPlace > MountainRange       0.35      0.91      0.50       244
#                                     Place > NaturalPlace > Volcano       0.00      0.00      0.00        74
#                                     Place > RaceTrack > Racecourse       0.00      0.00      0.00        26
#                             Place > RouteOfTransportation > Bridge       0.88      0.93      0.90       286
#                        Place > RouteOfTransportation > RailwayLine       0.51      0.81      0.62       286
#                               Place > RouteOfTransportation > Road       0.35      0.76      0.48       285
#                         Place > RouteOfTransportation > RoadTunnel       0.00      0.00      0.00        29
#                            Place > Satellite > ArtificialSatellite       0.00      0.00      0.00       235
#                                          Place > Settlement > Town       0.36      0.92      0.51       284
#                                       Place > Settlement > Village       0.78      0.97      0.86       285
#                              Place > SportFacility > CricketGround       0.00      0.00      0.00        24
#                                 Place > SportFacility > GolfCourse       0.00      0.00      0.00        34
#                                    Place > SportFacility > Stadium       0.42      0.80      0.55       285
#                                   Place > Station > RailwayStation       0.00      0.00      0.00       210
#                                             Place > Stream > Canal       0.00      0.00      0.00        40
#                                             Place > Stream > River       0.38      0.92      0.54       279
#                                         Place > Tower > Lighthouse       0.00      0.00      0.00       190
#                                            Place > Venue > Theatre       0.00      0.00      0.00        77
#                                       Species > Animal > Amphibian       0.68      0.84      0.75       285
#                                        Species > Animal > Arachnid       0.22      0.75      0.34       236
#                                            Species > Animal > Bird       0.36      0.76      0.49       286
#                                      Species > Animal > Crustacean       0.00      0.00      0.00       260
#                                            Species > Animal > Fish       0.00      0.00      0.00       285
#                                          Species > Animal > Insect       0.00      0.00      0.00       273
#                                        Species > Animal > Mollusca       0.51      0.93      0.66       287
#                                         Species > Animal > Reptile       0.00      0.00      0.00       283
#                                       Species > Eukaryote > Fungus       0.31      0.86      0.46       274
#                                   Species > FloweringPlant > Grape       0.00      0.00      0.00        36
#                                        Species > Horse > RaceHorse       0.60      0.94      0.73       284
#                                          Species > Plant > Conifer       0.00      0.00      0.00        70
#                                Species > Plant > CultivatedVariety       0.00      0.00      0.00       165
#                                            Species > Plant > Cycad       0.00      0.00      0.00        22
#                                             Species > Plant > Fern       0.00      0.00      0.00        89
#                                        Species > Plant > GreenAlga       0.00      0.00      0.00        35
#                                             Species > Plant > Moss       0.00      0.00      0.00        40
# SportsSeason > FootballLeagueSeason > NationalFootballLeagueSeason       0.82      0.95      0.88       286
#                   SportsSeason > SportsTeamSeason > BaseballSeason       0.00      0.00      0.00        24
#                   SportsSeason > SportsTeamSeason > NCAATeamSeason       0.91      0.96      0.94       286
#                 SportsSeason > SportsTeamSeason > SoccerClubSeason       0.77      0.84      0.80       283
#                                TopicalConcept > Genre > MusicGenre       0.00      0.00      0.00       117
#         UnitOfWork > LegalCase > SupremeCourtOfTheUnitedStatesCase       0.96      0.98      0.97       263
#                                             Work > Cartoon > Anime       0.00      0.00      0.00       129
#                                  Work > Cartoon > HollywoodCartoon       0.00      0.00      0.00       160
#                                          Work > Comic > ComicStrip       0.00      0.00      0.00        36
#                                               Work > Comic > Manga       0.60      0.96      0.74       288
#                               Work > Database > BiologicalDatabase       0.00      0.00      0.00        19
#                                         Work > MusicalWork > Album       0.51      0.87      0.64       285
#                             Work > MusicalWork > ArtistDiscography       0.00      0.00      0.00       264
#                     Work > MusicalWork > ClassicalMusicComposition       0.00      0.00      0.00        64
#                                       Work > MusicalWork > Musical       0.00      0.00      0.00       135
#                                        Work > MusicalWork > Single       0.85      0.91      0.88       284
#                      Work > PeriodicalLiterature > AcademicJournal       0.00      0.00      0.00       287
#                             Work > PeriodicalLiterature > Magazine       0.00      0.00      0.00       285
#                            Work > PeriodicalLiterature > Newspaper       0.00      0.00      0.00       282
#                                        Work > Software > VideoGame       0.89      0.91      0.90       287
#                           Work > Song > EurovisionSongContestEntry       0.40      0.87      0.55       106
#                                          Work > WrittenWork > Play       0.00      0.00      0.00       196
#                                          Work > WrittenWork > Poem       0.00      0.00      0.00        34
#
#                                                           accuracy                           0.40     36003
#                                                          macro avg       0.15      0.24      0.18     36003
#                                                       weighted avg       0.25      0.40      0.30     36003
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def predict_sentence(sentence, model, vocab, maxlen):
    model.eval()
    tokens = tokenize_text(sentence, vocab)
    tokens_padded = pad_sequences([tokens], maxlen)[0]
    tokens_tensor = torch.tensor([tokens_padded], dtype=torch.long).to(device)

    with torch.no_grad():
        outputs = model(tokens_tensor)
        pred = torch.argmax(outputs, dim=1)
        return le.inverse_transform(pred.cpu().numpy())[0]

# Example usage
sentence = "The new car is extremely fast"
prediction = predict_sentence(sentence, model, vocab, maxlen)
print(f"This sentence belongs to: {prediction}")

sentence = "This person is a works for the government now, he was the Presidential candidate."
prediction = predict_sentence(sentence, model, vocab, maxlen)
print(f"This sentence belongs to: {prediction}")
# Out:
# This sentence belongs to: Place > NaturalPlace > MountainRange
# This sentence belongs to: Agent > Athlete > GaelicGamesPlayer

# %%
# Tokenizer
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]

# %%
class TextDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encoding = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'label': torch.tensor(label, dtype=torch.long)
        }

# %%
max_len = 128
batch_size = 32

train_dataset = TextDataset(train_df['text'].tolist(), train_df['label_encoded'].tolist(), tokenizer, max_len)
val_dataset = TextDataset(val_df['text'].tolist(), val_df['label_encoded'].tolist(), tokenizer, max_len)
test_dataset = TextDataset(test_df['text'].tolist(), test_df['label_encoded'].tolist(), tokenizer, max_len)

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %%
class MultiLabelBERTModel(torch.nn.Module):
    def __init__(self, num_labels):
        super().__init__()
        self.bert = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=num_labels)

    def forward(self, input_ids, attention_mask):
        output = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        return output.logits

num_labels = len(le.classes_)
model = MultiLabelBERTModel(num_labels=num_labels)
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# device(type='cuda')

# %%
from tqdm import tqdm

def train_epoch(model, data_loader, optimizer, criterion):
    model.train()
    total_loss = 0
    loop = tqdm(data_loader, leave=True)

    for batch in loop:
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['label'].to(device)

        optimizer.zero_grad()
        outputs = model(input_ids=input_ids, attention_mask=attention_mask)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        total_loss += loss.item()

        # Update progress bar with the loss value
        loop.set_description(f"Train Loss: {total_loss / (loop.n + 1):.4f}")

    return total_loss / len(data_loader)

def evaluate(model, data_loader):
    model.eval()
    predictions, true_labels = [], []
    loop = tqdm(data_loader, leave=True)

    with torch.no_grad():
        for batch in loop:
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            labels = batch['label'].to(device)

            outputs = model(input_ids=input_ids, attention_mask=attention_mask)
            preds = torch.argmax(outputs, dim=1)

            predictions.extend(preds.cpu().numpy())
            true_labels.extend(labels.cpu().numpy())

            # Optionally, you can update the progress bar with additional info
            loop.set_description(f"Evaluating")

    return classification_report(true_labels, predictions, target_names=le.classes_)

# Training loop with tqdm progress bars
n = 3
for epoch in range(n):
    print(f'Epoch {epoch + 1}/{n}')
    train_loss = train_epoch(model, train_loader, optimizer, criterion)
    print(f'Training Loss: {train_loss}')
# Out:
# Epoch 1/3
# Train Loss: 2.6702:   1%|          | 66/7530 [00:47<1:30:13,  1.38it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-29c4995df2d8> in <cell line: 50>()
#      50 for epoch in range(n):
#      51     print(f'Epoch {epoch + 1}/{n}')
# ---> 52     train_loss = train_epoch(model, train_loader, optimizer, criterion)
#      53     print(f'Training Loss: {train_loss}')
#
# <ipython-input-11-29c4995df2d8> in train_epoch(model, data_loader, optimizer, criterion)
#       6     loop = tqdm(data_loader, leave=True)
#       7
# ----> 8     for batch in loop:
#       9         input_ids = batch['input_ids'].to(device)
#      10         attention_mask = batch['attention_mask'].to(device)
#
# /usr/local/lib/python3.10/dist-packages/tqdm/std.py in __iter__(self)
#    1179
#    1180         try:
# -> 1181             for obj in iterable:
#    1182                 yield obj
#    1183                 # Update and possibly print the progressbar.
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in __next__(self)
#     628                 # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629                 self._reset()  # type: ignore[call-arg]
# --> 630             data = self._next_data()
#     631             self._num_yielded += 1
#     632             if self._dataset_kind == _DatasetKind.Iterable and \
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py in _next_data(self)
#     671     def _next_data(self):
#     672         index = self._next_index()  # may raise StopIteration
# --> 673         data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     674         if self._pin_memory:
#     675             data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in fetch(self, possibly_batched_index)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/fetch.py in <listcomp>(.0)
#      50                 data = self.dataset.__getitems__(possibly_batched_index)
#      51             else:
# ---> 52                 data = [self.dataset[idx] for idx in possibly_batched_index]
#      53         else:
#      54             data = self.dataset[possibly_batched_index]
#
# <ipython-input-6-a9a168d55051> in __getitem__(self, idx)
#      12         text = self.texts[idx]
#      13         label = self.labels[idx]
# ---> 14         encoding = self.tokenizer.encode_plus(
#      15             text,
#      16             add_special_tokens=True,
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py in encode_plus(self, text, text_pair, add_special_tokens, padding, truncation, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#    3125         )
#    3126
# -> 3127         return self._encode_plus(
#    3128             text=text,
#    3129             text_pair=text_pair,
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils.py in _encode_plus(self, text, text_pair, add_special_tokens, padding_strategy, truncation_strategy, max_length, stride, is_split_into_words, pad_to_multiple_of, return_tensors, return_token_type_ids, return_attention_mask, return_overflowing_tokens, return_special_tokens_mask, return_offsets_mapping, return_length, verbose, **kwargs)
#     786             )
#     787
# --> 788         first_ids = get_input_ids(text)
#     789         second_ids = get_input_ids(text_pair) if text_pair is not None else None
#     790
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils.py in get_input_ids(text)
#     753         def get_input_ids(text):
#     754             if isinstance(text, str):
# --> 755                 tokens = self.tokenize(text, **kwargs)
#     756                 return self.convert_tokens_to_ids(tokens)
#     757             elif isinstance(text, (list, tuple)) and len(text) > 0 and isinstance(text[0], str):
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils.py in tokenize(self, text, **kwargs)
#     640             ]
#     641             pattern = r"(" + r"|".join(escaped_special_toks) + r")|" + r"(.+?)"
# --> 642             text = re.sub(pattern, lambda m: m.groups()[0] or m.groups()[1].lower(), text)
#     643
#     644         if split_special_tokens:
#
# /usr/lib/python3.10/re.py in sub(pattern, repl, string, count, flags)
#     207     a callable, it's passed the Match object and must return
#     208     a replacement string to be used."""
# --> 209     return _compile(pattern, flags).sub(repl, string, count)
#     210
#     211 def subn(pattern, repl, string, count=0, flags=0):
#
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils.py in <lambda>(m)
#     640             ]
#     641             pattern = r"(" + r"|".join(escaped_special_toks) + r")|" + r"(.+?)"
# --> 642             text = re.sub(pattern, lambda m: m.groups()[0] or m.groups()[1].lower(), text)
#     643
#     644         if split_special_tokens:
#
# KeyboardInterrupt:

# %%
# Evaluation
print("Validation Report:")
print(evaluate(model, val_loader))

print("Test Report:")
print(evaluate(model, test_loader))
